# %%
# !pip install gdown==4.6.0
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown==4.6.0 in /usr/local/lib/python3.8/dist-packages (4.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown==4.6.0) (1.15.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown==4.6.0) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown==4.6.0) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown==4.6.0) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown==4.6.0) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown==4.6.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown==4.6.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown==4.6.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown==4.6.0) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown==4.6.0) (1.7.1)

# %%
import os
import gdown
import zipfile
import pickle
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,BatchNormalization,Activation,Reshape,LSTM
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import RandomOverSampler
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from PIL import Image
from sklearn.model_selection import train_test_split
import os
import pickle
from sklearn.utils import compute_class_weight

# from PIL._imaging import display
from tensorflow import keras
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cv2
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, classification_report
from torchvision.io import read_image
from torchvision.io import read_image
import torchvision
from PIL import Image
from torchvision import transforms
from torchvision.utils import draw_bounding_boxes
import torch

# %% [markdown]
# ### Download the dataset from google drive (Optional if you do not have the dataset)

# %%
# https://drive.google.com/file/d/1YysOEXW-OjCwfS0tXu87ANtuHjPfDkJ1/view?usp=share_link
# Collected the id from drive link
# 1YysOEXW-OjCwfS0tXu87ANtuHjPfDkJ1
# !gdown --id 1YysOEXW-OjCwfS0tXu87ANtuHjPfDkJ1
# !pip install --upgrade --no-cache-dir gdown
# !gdown --no-cookies https://drive.google.com/uc?id=1dcO2Hyery3NbwPGRs11wlGnv6LIyhsUC
# !gdown https://drive.google.com/file/d/1dcO2Hyery3NbwPGRs11wlGnv6LIyhsUC/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dcO2Hyery3NbwPGRs11wlGnv6LIyhsUC
# To: /content/dataset.zip
# 100% 417M/417M [00:01<00:00, 230MB/s]

# %%
data_zip=zipfile.ZipFile('dataset.zip')
data_zip.extractall()
data_zip.close()

# %% [markdown]
# # Pre-Processing

# %%
# Creating the "model" folder for saving the "Best Model"
if not (os.path.exists('model')):
    os.mkdir('model')

# %%
def parse_annotation(path):
    tree = ET.parse(path)
    root = tree.getroot()
    constants = {}
    objects = [child for child in root if child.tag == 'object']
    for element in tree.iter():
        if element.tag == 'filename':
            constants['file'] = element.text[0:-4]
        if element.tag == 'size':
            for dim in list(element):
                if dim.tag == 'width':
                    constants['width'] = int(dim.text)
                if dim.tag == 'height':
                    constants['height'] = int(dim.text)
                if dim.tag == 'depth':
                    constants['depth'] = int(dim.text)
    object_params = [parse_annotation_object(obj) for obj in objects]
    full_result = [merge(constants, ob) for ob in object_params]
    return full_result

# %%
def parse_annotation_object(annotation_object):
    params = {}
    for param in list(annotation_object):
        if param.tag == 'name':
            params['name'] = param.text
        if param.tag == 'bndbox':
            for coord in list(param):
                if coord.tag == 'xmin':
                    params['xmin'] = int(coord.text)
                if coord.tag == 'ymin':
                    params['ymin'] = int(coord.text)
                if coord.tag == 'xmax':
                    params['xmax'] = int(coord.text)
                if coord.tag == 'ymax':
                    params['ymax'] = int(coord.text)

    return params

# %%
def merge(dict1, dict2):
    "Merges two dictionary"
    res = {**dict1, **dict2}
    return res

# %%
# def balance(xdf_data):
#     """
#     xdf_data: dataframe for both x & y
#     """
#     # Augmenting Minority Target Variabe

#     # The RandomOverSampler
#     ros = RandomOverSampler(random_state=55)
#     x = xdf_data.iloc[:, :-1]
#     y = xdf_data.iloc[:, -1]

#     # Augment the training data
#     X_ros_train, y_ros_train = ros.fit_resample(x, y)
#     new_data = pd.DataFrame(data=X_ros_train, columns=xdf_data.columns[:-1])
#     new_data['name'] = y_ros_train
#     return new_data

# %%
def crop_img(image_path, x_min, y_min, x_max, y_max):
    "crop faces from full picture"
    x_shift = (x_max - x_min) * 0.1
    y_shift = (y_max - y_min) * 0.1
    img = Image.open(image_path)
    cropped = img.crop((x_min - x_shift, y_min - y_shift, x_max + x_shift, y_max + y_shift))
    return cropped

# %%
def extract_faces(image_name, image_info, input_data_path):
    "extract faces from full image"
    faces = []
    df_one_img = image_info[image_info['file'] == image_name[:-4]][['xmin', 'ymin', 'xmax', 'ymax', 'name']]
    for row_num in range(len(df_one_img)):
        x_min, y_min, x_max, y_max, label = df_one_img.iloc[row_num]
        image_path = os.path.join(input_data_path, image_name)
        faces.append((crop_img(image_path, x_min, y_min, x_max, y_max), label, f'{image_name[:-4]}_{(x_min, y_min)}'))
    return faces

# %%
def save_image(image, image_name, output_data_path, dataset_type, label):
    output_path = os.path.join(output_data_path, dataset_type, label, f'{image_name}.png')
    image.save(output_path)

# %%
def preprocessing():
    "Main preprocessing function"
    input_data_path = str(os.getcwd()) + '/images'
    annotations_path = str(os.getcwd()) + "/annotations"
    images = [*os.listdir(str(os.getcwd()) + "/images")]
    output_data_path = '.'
    dataset = [parse_annotation(anno) for anno in glob.glob(annotations_path + "/*.xml")]

    full_dataset = sum(dataset, [])

    df = pd.DataFrame(full_dataset)
    print(df.shape)

    print(df.head())

    final_test_image = 'maksssksksss132'
    df_final_test = df.loc[df["file"] == final_test_image]
    images.remove(f'{final_test_image}.png')
    df = df.loc[df["file"] != final_test_image]

    print(df["name"].value_counts())

    # joined masked incorrectly with without mask
    df['name'] = df['name'].replace('mask_weared_incorrect', 'without_mask')

    # df.insert(9, 'label', df.name)
    # df = df.drop(['name'], axis=1)
    # df = balance(df)
    labels = df['name'].unique()
    directory = ['train', 'test', 'val']
    output_data_path = '.'
    for label in labels:
        for d in directory:
            path = os.path.join(output_data_path, d, label)
            if not os.path.exists(path):
                os.makedirs(path)
    cropped_faces = [extract_faces(img, df, input_data_path) for img in images]
    flat_cropped_faces = sum(cropped_faces, [])
    with_mask = [(img, image_name) for img, label, image_name in flat_cropped_faces if label == "with_mask"]

    without_mask = [(img, image_name) for img, label, image_name in flat_cropped_faces if label == "without_mask"]

    print(len(with_mask))
    print(len(without_mask))
    print(len(with_mask) + len(without_mask))

    train_with_mask, test_with_mask = train_test_split(with_mask, test_size=0.20, random_state=42)
    # print(len(train_with_mask), len(test_with_mask))
    test_with_mask, val_with_mask = train_test_split(test_with_mask, test_size=0.5, random_state=42)
    # print(len(test_with_mask), len(val_with_mask))
    train_without_mask, test_without_mask = train_test_split(without_mask, test_size=0.20, random_state=42)
    # print(len(train_without_mask), len(test_without_mask))
    test_without_mask, val_without_mask = train_test_split(test_without_mask, test_size=0.5, random_state=42)

    print(f"Train:\nWith Mask: {len(train_with_mask)}, Without Mask: {len(train_without_mask)}")
    print(f"Test:\nWith Mask: {len(test_with_mask)}, Without Mask: {len(test_without_mask)}")
    print(f"Val:\nWith Mask: {len(val_with_mask)}, Without Mask: {len(val_without_mask)}")

    # SAVE cropped faces into train-test-val folders seperately

    for image, image_name in train_with_mask:
        save_image(image, image_name, output_data_path, 'train', 'with_mask')

    for image, image_name in train_without_mask:
        save_image(image, image_name, output_data_path, 'train', 'without_mask')

    for image, image_name in test_with_mask:
        save_image(image, image_name, output_data_path, 'test', 'with_mask')

    for image, image_name in test_without_mask:
        save_image(image, image_name, output_data_path, 'test', 'without_mask')

    for image, image_name in val_with_mask:
        save_image(image, image_name, output_data_path, 'val', 'with_mask')

    for image, image_name in val_without_mask:
        save_image(image, image_name, output_data_path, 'val', 'without_mask')

# %%
preprocessing()
# Out:
# (4072, 9)
#               file  width  height  depth                   name  xmin  ymin  \
# 0  maksssksksss465    400     300      3              with_mask   231    42
# 1  maksssksksss756    400     267      3              with_mask   216    40
# 2  maksssksksss756    400     267      3  mask_weared_incorrect   114    54
# 3  maksssksksss163    400     300      3              with_mask   209   108
# 4  maksssksksss163    400     300      3              with_mask   161   124
#
#    xmax  ymax
# 0   297   128
# 1   251    82
# 2   151    91
# 3   226   126
# 4   184   152
# with_mask                3232
# without_mask              717
# mask_weared_incorrect     122
# Name: name, dtype: int64
# 3232
# 839
# 4071
# Train:
# With Mask: 2585, Without Mask: 671
# Test:
# With Mask: 323, Without Mask: 84
# Val:
# With Mask: 324, Without Mask: 84

# %% [markdown]
# # Train

# %%
def masked_model():
    model = Sequential()

    model.add(Conv2D(128, kernel_size=5, strides=1, padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=3, strides=2, padding='same'))

    model.add(Conv2D(72, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=5, strides=4, padding='same'))

    model.add(Conv2D(64, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=5, strides=4, padding='same'))

    model.add(Conv2D(64, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=4, strides=4, padding='same'))

    model.add(Reshape((-1, 64)))
    # LSTM
    model.add(LSTM(32))
    model.add(Dense(units=1, activation='sigmoid'))
    #
    model.summary()
    return model

# %%
# Data Augmentation for train images
def create_datagen():
    "Generates images with random augmentations"
    return ImageDataGenerator(
        rescale=1.0 / 255, horizontal_flip=True, zoom_range=0.1, shear_range=0.2, width_shift_range=0.1,
        height_shift_range=0.1, rotation_range=4, vertical_flip=False
    )

# %%
# Data Augmentation for validation and test images
def create_valDatagen():
    "Rescales images "
    return ImageDataGenerator(
        rescale=1.0 / 255
    )

# %%
def create_dataset_generator(datagen, batch_size, path,shuffle):
    "Data generator: reads images inn batches, encodes the target, reshapes the images"
    return datagen.flow_from_directory(
        directory=str(os.getcwd()) + path,
        target_size=(32, 32),
        class_mode="binary", batch_size=batch_size, shuffle=shuffle

    )

# %%
def prediction_label(predicts):
    "Set threshold for prediction"
    temp = []
    for i in predicts:
        if i[0] < 0.5:
            temp.append(0)
        else:
            temp.append(1)
    return temp

# %%
def train():
    batch_size = 8
    epochs = 150
    model = masked_model()
    datagen = create_datagen()
    val_datagen = create_valDatagen()
    train_generator = create_dataset_generator(datagen, batch_size, '/train',True)
    # Validation data
    val_generator = create_dataset_generator(val_datagen, batch_size, '/val',True)
    test_generator = create_dataset_generator(val_datagen, batch_size, '/test',False)
    
    # define clss weight to train with balanced dataset
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_generator.classes),y=train_generator.classes)

    train_class_weights = dict(enumerate(class_weights))
    print("####################################")
    print("Label 0: with mask\nLabel 1: Without Mask")
    print(f"Class Weight: {train_class_weights}")
    print("####################################")

    data_size = len(train_generator)
    steps_per_epoch = int(data_size / batch_size)
    print(f"steps_per_epoch: {steps_per_epoch}")
    val_steps = int(len(val_generator) // batch_size)
    print(f"val_steps: {val_steps}")
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(
        optimizer=opt,
        loss="binary_crossentropy",
        metrics=['accuracy', 'Recall', 'Precision']
        # metrics=['accuracy']
    )
    # early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
    # lrr = ReduceLROnPlateau(monitor='val_loss', patience=8, verbose=1, factor=0.5, min_lr=0.00001)
    model_history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        shuffle=True,
        verbose=1,
        validation_data=val_generator,
        validation_steps=val_steps,
        class_weight=train_class_weights,
        # callbacks=[early_stopping, lrr]
    )
    model_loss, model_acc, recall, precision= model.evaluate(test_generator)
    print("Test Scores:")
    print(
        f'Loss: {model_loss:.3f} || Accuracy: {model_acc * 100:.3f} || Recall: {recall * 100:.3f} || Precision: {precision * 100:.3f}')
    model.save_weights("model/masked_detection_model.h5")
    with open('model/history', 'wb') as file_pi:
        pickle.dump(model_history.history, file_pi)

# %%
# Uncomment this part if you want to train the model
train()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)       9728
#
#  batch_normalization_12 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 128)       0
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 72)        83016
#
#  batch_normalization_13 (Bat  (None, 16, 16, 72)       288
#  chNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 72)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 4, 4, 72)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 64)          41536
#
#  batch_normalization_14 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  activation_14 (Activation)  (None, 4, 4, 64)          0
#
#  max_pooling2d_14 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 1, 1, 64)          36928
#
#  batch_normalization_15 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  activation_15 (Activation)  (None, 1, 1, 64)          0
#
#  max_pooling2d_15 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  reshape_3 (Reshape)         (None, 1, 64)             0
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 184,969
# Trainable params: 184,313
# Non-trainable params: 656
# _________________________________________________________________
# Found 3256 images belonging to 2 classes.
# Found 408 images belonging to 2 classes.
# Found 407 images belonging to 2 classes.
# ####################################
# Label 0: with mask
# Label 1: Without Mask
# Class Weight: {0: 0.6297872340425532, 1: 2.4262295081967213}
# ####################################
# steps_per_epoch: 50
# val_steps: 6
# Epoch 1/150
# 50/50 [==============================] - 4s 34ms/step - loss: 0.6331 - accuracy: 0.5950 - recall: 0.7432 - precision: 0.2778 - val_loss: 0.6942 - val_accuracy: 0.3125 - val_recall: 1.0000 - val_precision: 0.3125
# Epoch 2/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.5650 - accuracy: 0.7200 - recall: 0.8767 - precision: 0.3832 - val_loss: 0.7168 - val_accuracy: 0.2292 - val_recall: 1.0000 - val_precision: 0.2292
# Epoch 3/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.5500 - accuracy: 0.7525 - recall: 0.8778 - precision: 0.4731 - val_loss: 0.7453 - val_accuracy: 0.2500 - val_recall: 1.0000 - val_precision: 0.2500
# Epoch 4/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4802 - accuracy: 0.7550 - recall: 0.9375 - precision: 0.4464 - val_loss: 0.7841 - val_accuracy: 0.2292 - val_recall: 1.0000 - val_precision: 0.2292
# Epoch 5/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4403 - accuracy: 0.7800 - recall: 0.9342 - precision: 0.4610 - val_loss: 0.8754 - val_accuracy: 0.1250 - val_recall: 1.0000 - val_precision: 0.1250
# Epoch 6/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4213 - accuracy: 0.8275 - recall: 0.9157 - precision: 0.5507 - val_loss: 0.7960 - val_accuracy: 0.2083 - val_recall: 1.0000 - val_precision: 0.2083
# Epoch 7/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.3950 - accuracy: 0.8025 - recall: 0.9189 - precision: 0.4823 - val_loss: 0.9709 - val_accuracy: 0.2500 - val_recall: 1.0000 - val_precision: 0.2500
# Epoch 8/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.3881 - accuracy: 0.8600 - recall: 0.9222 - precision: 0.6288 - val_loss: 0.9673 - val_accuracy: 0.3125 - val_recall: 1.0000 - val_precision: 0.3125
# Epoch 9/150
# 50/50 [==============================] - 1s 24ms/step - loss: 0.3512 - accuracy: 0.8725 - recall: 0.9011 - precision: 0.6613 - val_loss: 0.6873 - val_accuracy: 0.6042 - val_recall: 1.0000 - val_precision: 0.3448
# Epoch 10/150
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3596 - accuracy: 0.8550 - recall: 0.9070 - precision: 0.6094 - val_loss: 0.2582 - val_accuracy: 0.9583 - val_recall: 0.8889 - val_precision: 0.8889
# Epoch 11/150
# 50/50 [==============================] - 2s 33ms/step - loss: 0.3409 - accuracy: 0.8650 - recall: 0.8861 - precision: 0.6087 - val_loss: 0.5272 - val_accuracy: 0.7708 - val_recall: 0.7692 - val_precision: 0.5556
# Epoch 12/150
# 50/50 [==============================] - 1s 23ms/step - loss: 0.3846 - accuracy: 0.8500 - recall: 0.8452 - precision: 0.6017 - val_loss: 0.5273 - val_accuracy: 0.7500 - val_recall: 1.0000 - val_precision: 0.5200
# Epoch 13/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2798 - accuracy: 0.8975 - recall: 0.9367 - precision: 0.6727 - val_loss: 0.4005 - val_accuracy: 0.8542 - val_recall: 1.0000 - val_precision: 0.5000
# Epoch 14/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.3019 - accuracy: 0.8850 - recall: 0.9200 - precision: 0.6330 - val_loss: 0.4058 - val_accuracy: 0.8958 - val_recall: 0.9167 - val_precision: 0.7333
# Epoch 15/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.3116 - accuracy: 0.8700 - recall: 0.8642 - precision: 0.6306 - val_loss: 0.4908 - val_accuracy: 0.7917 - val_recall: 1.0000 - val_precision: 0.5455
# Epoch 16/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.3127 - accuracy: 0.8925 - recall: 0.8864 - precision: 0.7027 - val_loss: 0.2994 - val_accuracy: 0.8750 - val_recall: 1.0000 - val_precision: 0.6250
# Epoch 17/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2521 - accuracy: 0.9000 - recall: 0.9114 - precision: 0.6857 - val_loss: 0.2635 - val_accuracy: 0.9167 - val_recall: 0.8462 - val_precision: 0.8462
# Epoch 18/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2341 - accuracy: 0.9275 - recall: 0.9302 - precision: 0.7767 - val_loss: 0.1796 - val_accuracy: 0.9375 - val_recall: 0.8000 - val_precision: 0.6667
# Epoch 19/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.3493 - accuracy: 0.8625 - recall: 0.8265 - precision: 0.6807 - val_loss: 0.2677 - val_accuracy: 0.8750 - val_recall: 0.7273 - val_precision: 0.7273
# Epoch 20/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2434 - accuracy: 0.9000 - recall: 0.9176 - precision: 0.7027 - val_loss: 0.2268 - val_accuracy: 0.9167 - val_recall: 0.6667 - val_precision: 0.4000
# Epoch 21/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2998 - accuracy: 0.8900 - recall: 0.8734 - precision: 0.6699 - val_loss: 0.1620 - val_accuracy: 0.9167 - val_recall: 0.8000 - val_precision: 0.5714
# Epoch 22/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2773 - accuracy: 0.9000 - recall: 0.9080 - precision: 0.7117 - val_loss: 0.4596 - val_accuracy: 0.7917 - val_recall: 1.0000 - val_precision: 0.5000
# Epoch 23/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2785 - accuracy: 0.9000 - recall: 0.9059 - precision: 0.7064 - val_loss: 0.2917 - val_accuracy: 0.8542 - val_recall: 0.7500 - val_precision: 0.5455
# Epoch 24/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2698 - accuracy: 0.8950 - recall: 0.8675 - precision: 0.6990 - val_loss: 0.2576 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.6923
# Epoch 25/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2259 - accuracy: 0.9175 - recall: 0.9259 - precision: 0.7353 - val_loss: 0.1754 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.8750
# Epoch 26/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2400 - accuracy: 0.9100 - recall: 0.8806 - precision: 0.6782 - val_loss: 0.2870 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.6250
# Epoch 27/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2543 - accuracy: 0.9125 - recall: 0.9059 - precision: 0.7404 - val_loss: 0.4151 - val_accuracy: 0.8125 - val_recall: 0.9091 - val_precision: 0.5556
# Epoch 28/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2730 - accuracy: 0.8775 - recall: 0.9036 - precision: 0.6466 - val_loss: 0.4721 - val_accuracy: 0.7917 - val_recall: 1.0000 - val_precision: 0.4118
# Epoch 29/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2282 - accuracy: 0.9225 - recall: 0.9079 - precision: 0.7419 - val_loss: 0.1594 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.6250
# Epoch 30/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2646 - accuracy: 0.9025 - recall: 0.8571 - precision: 0.7021 - val_loss: 0.3559 - val_accuracy: 0.8750 - val_recall: 1.0000 - val_precision: 0.7000
# Epoch 31/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2452 - accuracy: 0.9075 - recall: 0.8846 - precision: 0.7113 - val_loss: 0.3232 - val_accuracy: 0.8542 - val_recall: 0.9091 - val_precision: 0.6250
# Epoch 32/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2091 - accuracy: 0.9200 - recall: 0.8966 - precision: 0.7723 - val_loss: 0.1471 - val_accuracy: 0.9583 - val_recall: 0.8000 - val_precision: 1.0000
# Epoch 33/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2116 - accuracy: 0.9250 - recall: 0.9565 - precision: 0.7097 - val_loss: 0.2980 - val_accuracy: 0.9167 - val_recall: 0.8750 - val_precision: 0.7000
# Epoch 34/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2467 - accuracy: 0.9050 - recall: 0.8916 - precision: 0.7184 - val_loss: 0.0722 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 35/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2095 - accuracy: 0.9200 - recall: 0.9186 - precision: 0.7596 - val_loss: 0.1858 - val_accuracy: 0.9375 - val_recall: 0.6667 - val_precision: 1.0000
# Epoch 36/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2617 - accuracy: 0.8900 - recall: 0.9444 - precision: 0.6296 - val_loss: 0.2399 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.6923
# Epoch 37/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2205 - accuracy: 0.9350 - recall: 0.8977 - precision: 0.8229 - val_loss: 0.2712 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.7368
# Epoch 38/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1936 - accuracy: 0.9225 - recall: 0.9254 - precision: 0.7045 - val_loss: 0.1062 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.8889
# Epoch 39/150
# 50/50 [==============================] - 1s 22ms/step - loss: 0.1834 - accuracy: 0.9225 - recall: 0.9444 - precision: 0.7158 - val_loss: 0.1255 - val_accuracy: 0.9583 - val_recall: 0.8182 - val_precision: 1.0000
# Epoch 40/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2310 - accuracy: 0.9225 - recall: 0.8714 - precision: 0.7349 - val_loss: 1.2884 - val_accuracy: 0.4583 - val_recall: 1.0000 - val_precision: 0.1875
# Epoch 41/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2750 - accuracy: 0.8975 - recall: 0.8523 - precision: 0.7282 - val_loss: 0.0683 - val_accuracy: 0.9583 - val_recall: 0.9000 - val_precision: 0.9000
# Epoch 42/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2171 - accuracy: 0.9175 - recall: 0.9146 - precision: 0.7426 - val_loss: 0.1664 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.6667
# Epoch 43/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1846 - accuracy: 0.9300 - recall: 0.8986 - precision: 0.7470 - val_loss: 0.1395 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8333
# Epoch 44/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1989 - accuracy: 0.9325 - recall: 0.9036 - precision: 0.7979 - val_loss: 1.0317 - val_accuracy: 0.5625 - val_recall: 1.0000 - val_precision: 0.2759
# Epoch 45/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1989 - accuracy: 0.9075 - recall: 0.9231 - precision: 0.7368 - val_loss: 0.1841 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.7895
# Epoch 46/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2008 - accuracy: 0.9175 - recall: 0.9268 - precision: 0.7379 - val_loss: 0.2366 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.7000
# Epoch 47/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1669 - accuracy: 0.9425 - recall: 0.9589 - precision: 0.7778 - val_loss: 0.1449 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9167
# Epoch 48/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1603 - accuracy: 0.9500 - recall: 0.9438 - precision: 0.8485 - val_loss: 0.3255 - val_accuracy: 0.8125 - val_recall: 1.0000 - val_precision: 0.4375
# Epoch 49/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2057 - accuracy: 0.9325 - recall: 0.9375 - precision: 0.7732 - val_loss: 0.1350 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8000
# Epoch 50/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1898 - accuracy: 0.9250 - recall: 0.9583 - precision: 0.7188 - val_loss: 0.1004 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9091
# Epoch 51/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2332 - accuracy: 0.9150 - recall: 0.8987 - precision: 0.7320 - val_loss: 0.2052 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.8333
# Epoch 52/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1807 - accuracy: 0.9300 - recall: 0.9383 - precision: 0.7677 - val_loss: 0.2781 - val_accuracy: 0.8958 - val_recall: 0.8889 - val_precision: 0.6667
# Epoch 53/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2776 - accuracy: 0.9175 - recall: 0.9130 - precision: 0.7706 - val_loss: 0.7260 - val_accuracy: 0.7083 - val_recall: 1.0000 - val_precision: 0.4615
# Epoch 54/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1971 - accuracy: 0.9175 - recall: 0.9024 - precision: 0.7475 - val_loss: 0.4902 - val_accuracy: 0.8125 - val_recall: 1.0000 - val_precision: 0.5000
# Epoch 55/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1566 - accuracy: 0.9350 - recall: 0.9651 - precision: 0.7830 - val_loss: 0.3195 - val_accuracy: 0.8542 - val_recall: 1.0000 - val_precision: 0.5333
# Epoch 56/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1930 - accuracy: 0.9175 - recall: 0.8987 - precision: 0.7396 - val_loss: 0.4714 - val_accuracy: 0.8333 - val_recall: 0.7500 - val_precision: 0.5000
# Epoch 57/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2083 - accuracy: 0.9300 - recall: 0.9310 - precision: 0.7864 - val_loss: 0.2386 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.6923
# Epoch 58/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1579 - accuracy: 0.9150 - recall: 0.9733 - precision: 0.6952 - val_loss: 0.1486 - val_accuracy: 0.9583 - val_recall: 0.9000 - val_precision: 0.9000
# Epoch 59/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1489 - accuracy: 0.9475 - recall: 0.9565 - precision: 0.7857 - val_loss: 0.1431 - val_accuracy: 0.9167 - val_recall: 0.8750 - val_precision: 0.7000
# Epoch 60/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1791 - accuracy: 0.9350 - recall: 0.9500 - precision: 0.7755 - val_loss: 0.0734 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.8000
# Epoch 61/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1586 - accuracy: 0.9275 - recall: 0.9467 - precision: 0.7396 - val_loss: 0.1165 - val_accuracy: 0.9375 - val_recall: 0.8889 - val_precision: 0.8000
# Epoch 62/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2448 - accuracy: 0.9175 - recall: 0.9041 - precision: 0.7174 - val_loss: 0.4498 - val_accuracy: 0.8333 - val_recall: 0.5000 - val_precision: 0.2500
# Epoch 63/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1785 - accuracy: 0.9250 - recall: 0.9398 - precision: 0.7573 - val_loss: 0.2032 - val_accuracy: 0.8958 - val_recall: 0.8889 - val_precision: 0.6667
# Epoch 64/150
# 50/50 [==============================] - 1s 27ms/step - loss: 0.1940 - accuracy: 0.9450 - recall: 0.9255 - precision: 0.8529 - val_loss: 0.2937 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.7368
# Epoch 65/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1970 - accuracy: 0.9250 - recall: 0.9375 - precision: 0.7895 - val_loss: 0.2632 - val_accuracy: 0.8542 - val_recall: 0.8889 - val_precision: 0.5714
# Epoch 66/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2438 - accuracy: 0.9150 - recall: 0.8936 - precision: 0.7778 - val_loss: 0.1638 - val_accuracy: 0.9583 - val_recall: 0.8000 - val_precision: 1.0000
# Epoch 67/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1572 - accuracy: 0.9375 - recall: 0.9655 - precision: 0.7925 - val_loss: 0.2925 - val_accuracy: 0.8958 - val_recall: 0.8333 - val_precision: 0.5556
# Epoch 68/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1824 - accuracy: 0.9175 - recall: 0.9500 - precision: 0.7238 - val_loss: 0.1265 - val_accuracy: 0.9167 - val_recall: 0.8000 - val_precision: 0.5714
# Epoch 69/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1974 - accuracy: 0.9400 - recall: 0.9412 - precision: 0.8081 - val_loss: 0.2349 - val_accuracy: 0.9167 - val_recall: 0.8462 - val_precision: 0.8462
# Epoch 70/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1955 - accuracy: 0.9175 - recall: 0.9250 - precision: 0.7327 - val_loss: 0.1952 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.5714
# Epoch 71/150
# 50/50 [==============================] - 1s 22ms/step - loss: 0.1702 - accuracy: 0.9325 - recall: 0.9625 - precision: 0.7624 - val_loss: 0.2128 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8571
# Epoch 72/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1721 - accuracy: 0.9400 - recall: 0.9535 - precision: 0.8039 - val_loss: 0.3174 - val_accuracy: 0.8542 - val_recall: 1.0000 - val_precision: 0.6500
# Epoch 73/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1759 - accuracy: 0.9225 - recall: 0.9500 - precision: 0.7379 - val_loss: 0.0994 - val_accuracy: 0.9167 - val_recall: 0.8000 - val_precision: 0.8000
# Epoch 74/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1458 - accuracy: 0.9400 - recall: 0.9583 - precision: 0.7667 - val_loss: 0.0950 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.7778
# Epoch 75/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2231 - accuracy: 0.9225 - recall: 0.8889 - precision: 0.7660 - val_loss: 0.1731 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.7500
# Epoch 76/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1724 - accuracy: 0.9125 - recall: 0.9367 - precision: 0.7115 - val_loss: 0.2106 - val_accuracy: 0.9583 - val_recall: 0.8750 - val_precision: 0.8750
# Epoch 77/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2450 - accuracy: 0.9200 - recall: 0.9032 - precision: 0.7850 - val_loss: 0.3397 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.6429
# Epoch 78/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2134 - accuracy: 0.9200 - recall: 0.9362 - precision: 0.7719 - val_loss: 0.1939 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.6923
# Epoch 79/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1787 - accuracy: 0.9225 - recall: 0.9462 - precision: 0.7719 - val_loss: 0.2030 - val_accuracy: 0.9375 - val_recall: 0.7273 - val_precision: 1.0000
# Epoch 80/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1398 - accuracy: 0.9400 - recall: 0.9875 - precision: 0.7745 - val_loss: 0.2648 - val_accuracy: 0.8958 - val_recall: 0.8182 - val_precision: 0.7500
# Epoch 81/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1177 - accuracy: 0.9500 - recall: 0.9886 - precision: 0.8208 - val_loss: 0.1408 - val_accuracy: 0.9583 - val_recall: 0.8333 - val_precision: 0.8333
# Epoch 82/150
# 50/50 [==============================] - 1s 24ms/step - loss: 0.1680 - accuracy: 0.9425 - recall: 0.9670 - precision: 0.8148 - val_loss: 0.1380 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.6154
# Epoch 83/150
# 50/50 [==============================] - 1s 23ms/step - loss: 0.2330 - accuracy: 0.9150 - recall: 0.9231 - precision: 0.7568 - val_loss: 0.2475 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.6154
# Epoch 84/150
# 50/50 [==============================] - 1s 24ms/step - loss: 0.1775 - accuracy: 0.9400 - recall: 0.9750 - precision: 0.7800 - val_loss: 0.1713 - val_accuracy: 0.9375 - val_recall: 0.8750 - val_precision: 0.7778
# Epoch 85/150
# 50/50 [==============================] - 1s 25ms/step - loss: 0.1634 - accuracy: 0.9200 - recall: 0.9870 - precision: 0.7103 - val_loss: 0.0677 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9167
# Epoch 86/150
# 50/50 [==============================] - 1s 25ms/step - loss: 0.1590 - accuracy: 0.9450 - recall: 0.9494 - precision: 0.8065 - val_loss: 0.1201 - val_accuracy: 0.9375 - val_recall: 0.9091 - val_precision: 0.8333
# Epoch 87/150
# 50/50 [==============================] - 1s 25ms/step - loss: 0.1707 - accuracy: 0.9450 - recall: 0.9149 - precision: 0.8600 - val_loss: 0.3209 - val_accuracy: 0.8958 - val_recall: 0.7778 - val_precision: 0.7000
# Epoch 88/150
# 50/50 [==============================] - 1s 23ms/step - loss: 0.1902 - accuracy: 0.9075 - recall: 0.9302 - precision: 0.7207 - val_loss: 0.1773 - val_accuracy: 0.9375 - val_recall: 0.8000 - val_precision: 0.6667
# Epoch 89/150
# 50/50 [==============================] - 1s 23ms/step - loss: 0.2155 - accuracy: 0.9175 - recall: 0.9103 - precision: 0.7320 - val_loss: 0.3268 - val_accuracy: 0.8333 - val_recall: 1.0000 - val_precision: 0.5556
# Epoch 90/150
# 50/50 [==============================] - 1s 22ms/step - loss: 0.1909 - accuracy: 0.9300 - recall: 0.9070 - precision: 0.7959 - val_loss: 0.1858 - val_accuracy: 0.9167 - val_recall: 0.7143 - val_precision: 0.7143
# Epoch 91/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1580 - accuracy: 0.9325 - recall: 0.9880 - precision: 0.7593 - val_loss: 0.2260 - val_accuracy: 0.9167 - val_recall: 0.9091 - val_precision: 0.7692
# Epoch 92/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1638 - accuracy: 0.9225 - recall: 0.9143 - precision: 0.7191 - val_loss: 0.1228 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8000
# Epoch 93/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1463 - accuracy: 0.9375 - recall: 0.9551 - precision: 0.8019 - val_loss: 0.1917 - val_accuracy: 0.8750 - val_recall: 0.9000 - val_precision: 0.6429
# Epoch 94/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2347 - accuracy: 0.9300 - recall: 0.9485 - precision: 0.8000 - val_loss: 0.0307 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 95/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1332 - accuracy: 0.9425 - recall: 0.9574 - precision: 0.8257 - val_loss: 0.1608 - val_accuracy: 0.9375 - val_recall: 0.8889 - val_precision: 0.8000
# Epoch 96/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1178 - accuracy: 0.9550 - recall: 0.9770 - precision: 0.8416 - val_loss: 0.1110 - val_accuracy: 0.9583 - val_recall: 0.8462 - val_precision: 1.0000
# Epoch 97/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2017 - accuracy: 0.9325 - recall: 0.8941 - precision: 0.8085 - val_loss: 0.2359 - val_accuracy: 0.9167 - val_recall: 0.8462 - val_precision: 0.8462
# Epoch 98/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1461 - accuracy: 0.9300 - recall: 0.9610 - precision: 0.7475 - val_loss: 0.1657 - val_accuracy: 0.9167 - val_recall: 0.9000 - val_precision: 0.7500
# Epoch 99/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2209 - accuracy: 0.9125 - recall: 0.9101 - precision: 0.7500 - val_loss: 0.2116 - val_accuracy: 0.9167 - val_recall: 0.8333 - val_precision: 0.8333
# Epoch 100/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1572 - accuracy: 0.9325 - recall: 0.9451 - precision: 0.7963 - val_loss: 0.0897 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9375
# Epoch 101/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2026 - accuracy: 0.9150 - recall: 0.8854 - precision: 0.7870 - val_loss: 0.0972 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8000
# Epoch 102/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1520 - accuracy: 0.9375 - recall: 0.9620 - precision: 0.7755 - val_loss: 0.1035 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8000
# Epoch 103/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1899 - accuracy: 0.9300 - recall: 0.9485 - precision: 0.8000 - val_loss: 0.0556 - val_accuracy: 0.9792 - val_recall: 0.8333 - val_precision: 1.0000
# Epoch 104/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1273 - accuracy: 0.9550 - recall: 0.9518 - precision: 0.8495 - val_loss: 0.1019 - val_accuracy: 0.9583 - val_recall: 0.8000 - val_precision: 0.8000
# Epoch 105/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1663 - accuracy: 0.9250 - recall: 0.9524 - precision: 0.7547 - val_loss: 0.2083 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.5455
# Epoch 106/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1735 - accuracy: 0.9425 - recall: 0.9518 - precision: 0.8061 - val_loss: 0.2958 - val_accuracy: 0.8958 - val_recall: 0.9091 - val_precision: 0.7143
# Epoch 107/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1787 - accuracy: 0.9300 - recall: 0.9545 - precision: 0.7778 - val_loss: 0.0952 - val_accuracy: 0.9583 - val_recall: 0.9091 - val_precision: 0.9091
# Epoch 108/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1415 - accuracy: 0.9500 - recall: 0.9571 - precision: 0.7976 - val_loss: 0.2361 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.6667
# Epoch 109/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1595 - accuracy: 0.9500 - recall: 0.9420 - precision: 0.8025 - val_loss: 0.7909 - val_accuracy: 0.6667 - val_recall: 1.0000 - val_precision: 0.3846
# Epoch 110/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1844 - accuracy: 0.9250 - recall: 0.9306 - precision: 0.7283 - val_loss: 0.0693 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9000
# Epoch 111/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1777 - accuracy: 0.9425 - recall: 0.9211 - precision: 0.8046 - val_loss: 0.1663 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.5556
# Epoch 112/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1660 - accuracy: 0.9500 - recall: 0.9545 - precision: 0.8400 - val_loss: 0.3011 - val_accuracy: 0.8750 - val_recall: 1.0000 - val_precision: 0.6471
# Epoch 113/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.2059 - accuracy: 0.9425 - recall: 0.9200 - precision: 0.8598 - val_loss: 0.2907 - val_accuracy: 0.8958 - val_recall: 0.8000 - val_precision: 0.7273
# Epoch 114/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1722 - accuracy: 0.9200 - recall: 0.9405 - precision: 0.7453 - val_loss: 0.3366 - val_accuracy: 0.8333 - val_recall: 1.0000 - val_precision: 0.7037
# Epoch 115/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0988 - accuracy: 0.9600 - recall: 0.9881 - precision: 0.8469 - val_loss: 0.1935 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8333
# Epoch 116/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1477 - accuracy: 0.9475 - recall: 0.9670 - precision: 0.8302 - val_loss: 0.0658 - val_accuracy: 0.9792 - val_recall: 0.9167 - val_precision: 1.0000
# Epoch 117/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1744 - accuracy: 0.9425 - recall: 0.9706 - precision: 0.8319 - val_loss: 0.1576 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8462
# Epoch 118/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1241 - accuracy: 0.9400 - recall: 0.9394 - precision: 0.7561 - val_loss: 0.2585 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.6667
# Epoch 119/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1812 - accuracy: 0.9550 - recall: 0.9310 - precision: 0.8710 - val_loss: 0.2289 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.6154
# Epoch 120/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1908 - accuracy: 0.9175 - recall: 0.9351 - precision: 0.7200 - val_loss: 0.1419 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8750
# Epoch 121/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1721 - accuracy: 0.9175 - recall: 0.8961 - precision: 0.7340 - val_loss: 0.2107 - val_accuracy: 0.9167 - val_recall: 0.9091 - val_precision: 0.7692
# Epoch 122/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1347 - accuracy: 0.9525 - recall: 0.9639 - precision: 0.8333 - val_loss: 0.1581 - val_accuracy: 0.9583 - val_recall: 0.9286 - val_precision: 0.9286
# Epoch 123/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1514 - accuracy: 0.9375 - recall: 0.9259 - precision: 0.7979 - val_loss: 0.2561 - val_accuracy: 0.8958 - val_recall: 1.0000 - val_precision: 0.5455
# Epoch 124/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1803 - accuracy: 0.9450 - recall: 0.9540 - precision: 0.8218 - val_loss: 0.1056 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8333
# Epoch 125/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1079 - accuracy: 0.9500 - recall: 0.9744 - precision: 0.8085 - val_loss: 0.2687 - val_accuracy: 0.9167 - val_recall: 0.8889 - val_precision: 0.7273
# Epoch 126/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1649 - accuracy: 0.9325 - recall: 0.9155 - precision: 0.7558 - val_loss: 0.0985 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8462
# Epoch 127/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1320 - accuracy: 0.9450 - recall: 0.9425 - precision: 0.8283 - val_loss: 0.0902 - val_accuracy: 0.9583 - val_recall: 0.8750 - val_precision: 0.8750
# Epoch 128/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1339 - accuracy: 0.9550 - recall: 0.9506 - precision: 0.8462 - val_loss: 0.1052 - val_accuracy: 0.9583 - val_recall: 0.9167 - val_precision: 0.9167
# Epoch 129/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1585 - accuracy: 0.9350 - recall: 0.9506 - precision: 0.7778 - val_loss: 0.0520 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.8889
# Epoch 130/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1965 - accuracy: 0.9250 - recall: 0.9195 - precision: 0.7767 - val_loss: 0.0811 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9091
# Epoch 131/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1532 - accuracy: 0.9250 - recall: 0.9518 - precision: 0.7524 - val_loss: 0.1797 - val_accuracy: 0.8958 - val_recall: 0.8000 - val_precision: 0.8571
# Epoch 132/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1227 - accuracy: 0.9525 - recall: 0.9747 - precision: 0.8191 - val_loss: 0.0703 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.8750
# Epoch 133/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1088 - accuracy: 0.9475 - recall: 0.9881 - precision: 0.8058 - val_loss: 0.2721 - val_accuracy: 0.8542 - val_recall: 0.8889 - val_precision: 0.5714
# Epoch 134/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1746 - accuracy: 0.9450 - recall: 0.9512 - precision: 0.8125 - val_loss: 0.0951 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.7143
# Epoch 135/150
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1607 - accuracy: 0.9475 - recall: 0.9432 - precision: 0.8384 - val_loss: 0.1226 - val_accuracy: 0.9583 - val_recall: 0.7143 - val_precision: 1.0000
# Epoch 136/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1773 - accuracy: 0.9300 - recall: 0.9383 - precision: 0.7677 - val_loss: 0.1444 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.6000
# Epoch 137/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1220 - accuracy: 0.9475 - recall: 0.9605 - precision: 0.8022 - val_loss: 0.2053 - val_accuracy: 0.8958 - val_recall: 0.9167 - val_precision: 0.7333
# Epoch 138/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1259 - accuracy: 0.9450 - recall: 0.9773 - precision: 0.8113 - val_loss: 0.1736 - val_accuracy: 0.9375 - val_recall: 1.0000 - val_precision: 0.8125
# Epoch 139/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1325 - accuracy: 0.9425 - recall: 0.9610 - precision: 0.7872 - val_loss: 0.3871 - val_accuracy: 0.8333 - val_recall: 0.8333 - val_precision: 0.4167
# Epoch 140/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1005 - accuracy: 0.9575 - recall: 0.9870 - precision: 0.8261 - val_loss: 0.0918 - val_accuracy: 0.9583 - val_recall: 0.8462 - val_precision: 1.0000
# Epoch 141/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1927 - accuracy: 0.9400 - recall: 0.9195 - precision: 0.8247 - val_loss: 0.0807 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.8750
# Epoch 142/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1238 - accuracy: 0.9400 - recall: 0.9630 - precision: 0.7879 - val_loss: 0.0477 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9091
# Epoch 143/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1599 - accuracy: 0.9400 - recall: 0.9348 - precision: 0.8269 - val_loss: 0.1549 - val_accuracy: 0.9375 - val_recall: 0.9091 - val_precision: 0.8333
# Epoch 144/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1507 - accuracy: 0.9450 - recall: 0.9412 - precision: 0.8247 - val_loss: 0.1761 - val_accuracy: 0.9167 - val_recall: 1.0000 - val_precision: 0.6667
# Epoch 145/150
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1224 - accuracy: 0.9550 - recall: 0.9529 - precision: 0.8526 - val_loss: 0.1009 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9000
# Epoch 146/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1608 - accuracy: 0.9300 - recall: 0.9425 - precision: 0.7810 - val_loss: 0.1564 - val_accuracy: 0.9375 - val_recall: 0.9333 - val_precision: 0.8750
# Epoch 147/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1263 - accuracy: 0.9425 - recall: 0.9730 - precision: 0.7742 - val_loss: 0.1607 - val_accuracy: 0.8750 - val_recall: 0.8889 - val_precision: 0.6154
# Epoch 148/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1110 - accuracy: 0.9625 - recall: 0.9744 - precision: 0.8539 - val_loss: 0.1338 - val_accuracy: 0.9583 - val_recall: 1.0000 - val_precision: 0.8000
# Epoch 149/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1626 - accuracy: 0.9275 - recall: 0.9302 - precision: 0.7767 - val_loss: 0.0714 - val_accuracy: 0.9792 - val_recall: 1.0000 - val_precision: 0.9231
# Epoch 150/150
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1617 - accuracy: 0.9275 - recall: 0.9263 - precision: 0.8000 - val_loss: 0.2892 - val_accuracy: 0.8750 - val_recall: 1.0000 - val_precision: 0.6250
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2422 - accuracy: 0.8870 - recall: 0.9881 - precision: 0.6484
# Test Scores:
# Loss: 0.242 || Accuracy: 88.698 || Recall: 98.810 || Precision: 64.844

# %% [markdown]
# # Test

# %%
def plot_loss_and_accuracy(history):
    "Plots loss and accuracy vs epochs"
    history_df = pd.DataFrame(history)
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))

    history_df.loc[0:, ['loss', 'val_loss']].plot(ax=ax[0])
    ax[0].set(xlabel='epoch number', ylabel='loss')

    history_df.loc[0:, ['accuracy', 'val_accuracy']].plot(ax=ax[1])
    ax[1].set(xlabel='epoch number', ylabel='accuracy')
    plt.show()

# %%
def evaluation(y, y_hat, title='Confusion Matrix'):
    "Plots the confusion matrix"
    cm = confusion_matrix(y, y_hat)
    sns.heatmap(cm, cmap='PuBu', annot=True, fmt='g', annot_kws={'size': 20})
    plt.xlabel('predicted', fontsize=18)
    plt.ylabel('actual', fontsize=18)
    plt.title(title, fontsize=18)

    plt.show()

# %%
def prediction_label(predicts):
    "Set threshold to predict labels"
    temp = []
    for i in predicts:
        if i[0] < 0.5:
            temp.append(0)
        else:
            temp.append(1)
    return temp

# %%
def test():
    batch_size = 8
    model = masked_model()
    model.load_weights('model/masked_detection_model.h5')
    with open('model/history', "rb") as file_pi:
        model_history = pickle.load(file_pi)
    val_datagen = create_valDatagen()
    test_generator = create_dataset_generator(val_datagen, batch_size, '/test',False)
    predictions = model.predict(test_generator)
    y_pred = prediction_label(predictions)
    y_pred = np.array(y_pred)
#     plot_loss_and_accuracy(model_history)
    y_true = test_generator.labels
    print(np.bincount(y_pred))
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(
        optimizer=opt,
        loss="binary_crossentropy",
        metrics=['accuracy', 'Recall', 'Precision']
    )
    model_loss, model_acc, recall, precision= model.evaluate(test_generator)
    F1 = 2 * (precision * recall) / (precision + recall)
    print(f"F1 Score - {F1:.4f}")
#     print(classification_report(y_true, y_pred))
#     evaluation(y_true, y_pred)
    return model,model_history,y_true,y_pred,test_generator

# %%
model,model_history,y_true,y_pred,test_generator=test()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 32, 32, 128)       9728
#
#  batch_normalization_16 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 128)       0
#
#  max_pooling2d_16 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 72)        83016
#
#  batch_normalization_17 (Bat  (None, 16, 16, 72)       288
#  chNormalization)
#
#  activation_17 (Activation)  (None, 16, 16, 72)        0
#
#  max_pooling2d_17 (MaxPoolin  (None, 4, 4, 72)         0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 64)          41536
#
#  batch_normalization_18 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  activation_18 (Activation)  (None, 4, 4, 64)          0
#
#  max_pooling2d_18 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 64)          36928
#
#  batch_normalization_19 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  activation_19 (Activation)  (None, 1, 1, 64)          0
#
#  max_pooling2d_19 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  reshape_4 (Reshape)         (None, 1, 64)             0
#
#  lstm_4 (LSTM)               (None, 32)                12416
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 184,969
# Trainable params: 184,313
# Non-trainable params: 656
# _________________________________________________________________
# Found 407 images belonging to 2 classes.
# 51/51 [==============================] - 1s 8ms/step
# [279 128]
# 51/51 [==============================] - 2s 10ms/step - loss: 0.2422 - accuracy: 0.8870 - recall: 0.9881 - precision: 0.6484
# F1 Score - 0.7830

# %%
plot_loss_and_accuracy(model_history)

# %%
evaluation(y_true, y_pred)

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92       323
#            1       0.65      0.99      0.78        84
#
#     accuracy                           0.89       407
#    macro avg       0.82      0.92      0.85       407
# weighted avg       0.92      0.89      0.89       407

# %% [markdown]
# # Test with new images

# %%
from keras.models import load_model
from tensorflow.keras.preprocessing import image
def load_image(img_path, show=False):
    img = image.load_img(img_path, target_size=(32, 32))
    img_tensor = image.img_to_array(img)                    # (height, width, channels)
    img_tensor = np.expand_dims(img_tensor, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img_tensor /= 255.                                      # imshow expects values in the range [0, 1]

    if show:
        plt.imshow(img_tensor[0])                           
        plt.axis('off')
        plt.show()

    return img_tensor
new_image = load_image('withoutmask.jpg')
predictions = model.predict(new_image)
if predictions[0][0]<0.5:
    print("With Mask")
else:
    print("With Out Mask")
# Out:
# 1/1 [==============================] - 1s 530ms/step
# With Mask

# %% [markdown]
# # Bouding Box

# %%
# randomly selects a image from the test set
paths = test_generator.filenames
a_img_rand = np.random.randint(0, len(paths))
img = cv2.imread(os.path.join('', 'test', paths[a_img_rand]))
colored_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(colored_img)

# %%
classes = test_generator.class_indices
# true_label = paths[a_img_rand].split('/')[0]
true_label = paths[a_img_rand]
predicted_label = list(classes)[y_pred[a_img_rand]]
print(f'{predicted_label} || {true_label}')
# Out:
# with_mask || with_mask/maksssksksss253_(209, 124).png

# %%
true_label
# Out:
# 'with_mask/maksssksksss253_(209, 124).png'

# %%
# Let's Create the label and original image and bbox value
true_label=true_label.split('/')
true_class=true_label[0]
true_label
# Out:
# ['with_mask', 'maksssksksss253_(209, 124).png']

# %%
originalimageinfo=true_label[1].split('_')
originalimageinfo
# Out:
# ['maksssksksss253', '(209, 124).png']

# %%
originalimagename="images/"+originalimageinfo[0]+".png"
originalimageAnnotations="annotations/"+originalimageinfo[0]+".xml"

# %%
originalimageinfo[1]=originalimageinfo[1].replace('.png','')
originalimageinfo[1]=originalimageinfo[1].replace(')','')
originalimageinfo[1]=originalimageinfo[1].replace('(','')
bbboxdimension=originalimageinfo[1].split(',')
bbboxdimension
# Out:
# ['209', ' 124']

# %%
# Read the annotation file for bounding box
box=[]
from xml.dom import minidom
file = minidom.parse(originalimageAnnotations)
bndbox = file.getElementsByTagName('bndbox')
for elem in bndbox:
    xmin=elem.getElementsByTagName('xmin')
    ymin=elem.getElementsByTagName('ymin')
    xmax=elem.getElementsByTagName('xmax')
    ymax=elem.getElementsByTagName('ymax')
    bbboxdimension[1]=bbboxdimension[1].replace(" ","")
    if xmin[0].firstChild.nodeValue==bbboxdimension[0] and  ymin[0].firstChild.nodeValue==bbboxdimension[1]:
        box.append(int(xmin[0].firstChild.nodeValue))
        box.append(int(ymin[0].firstChild.nodeValue))
        box.append(int(xmax[0].firstChild.nodeValue))
        box.append(int(ymax[0].firstChild.nodeValue))
        
    
print(box)
# Out:
# [209, 124, 237, 151]

# %%
img_original = Image.open(originalimagename)
img_predicted = Image.open(originalimagename)
img_original = img_predicted.convert('RGB')
img_predicted = img_predicted.convert('RGB')
img_original
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2B1C128040>

# %%
transform = transforms.PILToTensor()
img_original=transform(img_original)
img_predicted=transform(img_predicted)

# %%
# The format for boxes is list inside the list so we will make another list and append our box
# boxes=[[63,138,93,171]]
boxes=[]
boxes.append(box)
boxes=torch.tensor(boxes,dtype=torch.int)

# %% [markdown]
# ### Original Image Classification

# %%
original_label=[]
original_label.append(true_class)
img=draw_bounding_boxes(img_original, boxes, width=3, colors=(0,255,0),labels=original_label,font_size=4)
img = torchvision.transforms.ToPILImage()(img)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/utils.py:232: UserWarning: Argument 'font_size' will be ignored since 'font' is not set.
#   warnings.warn("Argument 'font_size' will be ignored since 'font' is not set.")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2B143B6820>

# %% [markdown]
# ### Predicated Image Classification

# %%
predicted_labels=[]
predicted_labels.append(predicted_label)
img=draw_bounding_boxes(img_predicted, boxes, width=3, colors=(0,255,0),labels=predicted_labels,font_size=4)
img = torchvision.transforms.ToPILImage()(img)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F2B6CAA38B0>
